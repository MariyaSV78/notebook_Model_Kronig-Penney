# %% [markdown]
# **General objective:** is to understand how a periodic potential gives rise to allowed and forbidden energy bands for an electron in a crystal.

# %% [markdown]
# The Kronig-Penney model, developed by Ralph Kronig and William Penney in 1931, is a simple, idealized model of a quantum mechanical system consisting of an infinite series of quantum wells, all of the same size $a$, separated by rectangular potential barriers of width $b$ and height $V_0$, with each "cell" (well + one barrier) having a length $d$, where $d=a+b$.

# %% [markdown]
# <div style="text-align: center;">
# <img src="model.png" alt="model" width="30%"  />
#
# Fig.1. The Kronig-Penney model.
# </div>

# %% [markdown]
# We consider an electron in a crystal modeled by a one-dimensional periodic potential of the Kronig–Penney type:
# - The potential consists of barriers of height $V_0$=1.5 eV and width $c$ = 0.3 nm.
# - Between the barriers, the electron moves freely over a distance $b$ = 0.6 nm.
# - The period of the potential is therefore $a = b+c$ = 0.9 nm.
#
# We choose the origin such that:
# - Free region: $V(x) = 0$, for $x ∈ [0,b[$.
# - Barrier region: $V(x) = V_0$, for $x ∈ [-c,0[$.
#
# We first consider the case where the energy $E$ of the electron’s eigenstate is less than $V_0$.

# %% [markdown]
# ## Dispersion relation
#
# 1. Write the Schrödinger equation in the two regions $[−c,0[$ and $[0,b[$.
#
# 2. Give the general forms of the solutions in each region.
#
# 3. Write the continuity conditions that must be imposed on $\psi(x)$ and $\psi '(x)$ at $x = 0$.
#
# 4. Recall Bloch’s theorem. Deduce from it the expression of the wave function in the interval $[b,a[$.
#
# 5. Write the continuity conditions that must be imposed on $\psi(x)$ and $\psi '(x)$ at $x = b$.
#
# 6. Show that the dispersion relation can be written, in the case $ 0 < E < V_0 $, as:
#
# $$
#   \cos(ka) = \cos(\alpha b)\cosh(\beta c)
#   - \frac{\alpha^2 - \beta^2}{2\alpha\beta} \sin(\alpha b)\sinh(\beta c)
# $$
# ⁡
# with
#
# $$
#   \alpha = \sqrt{\frac{2mE}{\hbar^2}}, \qquad
#   \beta = \sqrt{\frac{2m(V_0 - E)}{\hbar^2}}
# $$
#
# 7. Apply the same method to derive the dispersion relation in the case $V_0 < E$:
#
# $$
#   \cos(ka) = \cos(\alpha b)\cos(\kappa c)
#   - \frac{\alpha^2 + \kappa^2}{2\alpha\kappa} \sin(\alpha b)\sin(\kappa c)
# $$
#
# with
# $$
#   \alpha = \sqrt{\frac{2mE}{\hbar^2}}, \qquad
#   \kappa = \sqrt{\frac{2m(E - V_0)}{\hbar^2}}
# $$​

# %% [markdown]
# 1. Write the Schrödinger equation in the two regions $[−c,0[$ and $[0,b[$.
#
# The time-independent Schrödinger equation is
#
# $$
# - \frac{\hbar^2}{2m} \frac{d^2 \psi(x)}{dx^2} + V(x)\psi(x) = E\psi(x)
# $$
#
# where the potential V(x) is periodic: $V(x + a)=V(x), and $a$b is a lattice vector of the crystal.
#
# For the two regions:
#
# - **Region I** $[-c, 0[$ (barrier region, $V(x) = V_0$):
#
#   $$
#   -\frac{\hbar^2}{2m} \frac{d^2 \psi_I(x)}{dx^2} + V_0\psi_I(x) = E\psi_I(x)
#   \quad \Longrightarrow \quad
#   \frac{d^2 \psi_I(x)}{dx^2} = \frac{2m(V_0 - E)}{\hbar^2}\psi_I(x)
#   $$
#
# - **Region II** $[0, b[$ (free region, $V(x) = 0$):
#
#   $$
#   -\frac{\hbar^2}{2m} \frac{d^2 \psi_{II}(x)}{dx^2} = E\psi_{II}(x)
#   \quad \Longrightarrow \quad
#   \frac{d^2 \psi_{II}(x)}{dx^2} = -\frac{2mE}{\hbar^2}\psi_{II}(x)
#   $$
#
#
#
# With the standard notation
#
# $$
# \beta = \sqrt{\frac{2m(V_0 - E)}{\hbar^2}},
# \qquad
# \alpha = \sqrt{\frac{2mE}{\hbar^2}},
# $$
#
# we can write:
#
# $$
# \psi_I''(x) = \beta^2 \psi_I(x) \quad \text{for } x \in [-c, 0[.
# \qquad
# \psi_{II}''(x) = -\alpha^2 \psi_{II}(x) \quad \text{for } x \in [0, b[.
# $$

# %% [markdown]
# 2. Give the general forms of the solutions in each region.
#
# From the differential equations obtained previously the general solutions can be written as follows:
#
# - **Region I** $[-c, 0[$ (barrier region, $V(x) = V_0$):
#
#   Since the equation involves a positive exponent $\beta^2$,
#   the solution is a combination of exponential functions:
#   $$
#   \psi_I(x) = A e^{\beta x} + B e^{-\beta x},
#   $$
#   where $A$ and $B$ are constants determined by boundary conditions.
#
# - **Region II** $[0, b[$ (free region, $V(x) = 0$):
#
#   Since the equation involves a negative exponent $-\alpha^2$,
#   the solution is a combination of sine and cosine (or equivalently complex exponentials):
#   $$
#   \psi_{II}(x) = C e^{i\alpha x} + D e^{-i\alpha x},
#   $$
#   where $C$ and $D$ are constants determined by boundary conditions.

# %% [markdown]
# 3. Write the continuity conditions that must be imposed on $\psi(x)$ and $\psi '(x)$ at $x = 0$.
# - **Region I** $[-c, 0[$ (barrier region, $V(x) = V_0$):
# $$
# \psi_I(x)=A e^{\beta x}+B e^{-\beta x},
# \qquad
# \psi_I'(x)=\beta\bigl(A e^{\beta x}-B e^{-\beta x}\bigr),
# $$
#
# - **Region II** $[0, b[$ (free region, $V(x) = 0$):
# $$
# \psi_{II}(x)=C e^{i\alpha x}+D e^{-i\alpha x},
# \qquad
# \psi_{II}'(x)=i\alpha\bigl(C e^{i\alpha x}-D e^{-i\alpha x}\bigr).
# $$
#
# **Continuity at $x = 0 $** gives
# $$
# \psi_I(0)=\psi_{II}(0) \quad\Longrightarrow\quad A + B = C + D,
# $$
#
# $$
# \psi_I'(0)=\psi_{II}'(0) \quad\Longrightarrow\quad \beta(A - B)=i\alpha(C - D).
# $$
#
# Equivalently, as a linear system for $(A,B)$ in terms of $(C,D)$:
# $$
# \begin{pmatrix} 1 & 1 \\ \beta & -\beta \end{pmatrix}
# \begin{pmatrix} A \\ B \end{pmatrix}
# =
# \begin{pmatrix} 1 & 1 \\ i\alpha & -i\alpha \end{pmatrix}
# \begin{pmatrix} C \\ D \end{pmatrix}.
# $$

# %% [markdown]
# 4. Recall Bloch’s theorem. Deduce from it the expression of the wave function in the interval $[b,a[$.
# ---
# **Bloch's theorem:**
# For any wave function that satisfies the Schrödinger equation in a periodic potential, and for a translation by one **lattice vector $a$**, there exists  at least one vector $k$ such that:
#
# $$
# \psi(x+a)=e^{i k a}\,\psi(x),
# $$
# where $\psi$ is the wave function, $k$ is the crystal wave vector (**Bloch wave vector**).
#
# ---
#
# The barrier in the reference cell is $x\in[-c,0[$. Adding the period $a$ maps this barrier to the next cell
# $$
# [-c,0[ \xrightarrow{+a} [a-c,a[ = [b,a[.
# $$
# For $x\in[b,a[$ set $x-a\in[-c,0[$ and use Bloch's relation:
# $$
# \psi(x)=\psi((x-a)+a)=e^{i k a}\,\psi(x-a).
# $$
#
# Using the barrier solution in the reference cell,
# $$
# \psi_I(x-a)=A e^{\beta(x-a)}+B e^{-\beta(x-a)},
# $$
# we obtain solution for the wave function in the barrier of the next cell $x\in[b,a[$
# $$
# \boxed{\,\psi(x)=e^{i k a}\bigl[A e^{\beta(x-a)}+B e^{-\beta(x-a)}\bigr]\, }.
# $$

# %% [markdown]
# 5. Write the continuity conditions that must be imposed on $\psi(x)$ and $\psi '(x)$ at $x = b$.
#
# - **Region II** $[0, b[$ (free region, of the first cell, $V(x) = 0$):
# $$
# \psi_{II}(x)=C e^{i\alpha x}+D e^{-i\alpha x},
# \qquad
# \psi_{II}'(x)=i\alpha\bigl(C e^{i\alpha x}-D e^{-i\alpha x}\bigr).
# $$
#
# - **Region III** $[b, a[$ (barrier region in the next cell, $V(x) = V_0$):
# $$
# \psi_{III}(x)=e^{i k a} \bigl( A e^{\beta (x - a)}+B e^{-\beta (x - a)}\bigr),
# \qquad
# \psi_{III}'(x)=e^{i k a} \beta \bigl( A e^{\beta (x - a)}-B e^{-\beta (x - a)}\bigr).
# $$
#
# **Continuity conditions at $x=b$:**
#
# Wave function continuity:
# $$
# \psi_{II}(b) = \psi_{III}(b) \quad \Longrightarrow \quad
# C e^{i \alpha b} + D e^{-i \alpha b} = e^{i k a} \Bigl( A e^{\beta (b-a)} + B e^{-\beta (b-a)} \Bigr) = e^{i k a} \Bigl( A e^{\beta c} + B e^{-\beta c} \Bigr)
# $$
#
# Derivative continuity:
# $$
# \psi_{II}'(b) = \psi_{III}'(b) \quad \Longrightarrow \quad
# i \alpha \big( C e^{i \alpha b} - D e^{-i \alpha b} \big) = e^{i k a} \beta \big( A e^{\beta (b-a)} - B e^{-\beta (b-a)} \big) = e^{i k a} \beta \big( A e^{\beta c} - B e^{-\beta c} \big)
# $$
#
# Note:
# - $C,D$ are the coefficients in the free region of the first cell (Region II).
# - $A,B$ are the coefficients in the barrier of the next cell (Region III).
# - $e^{i k a}$ comes from Bloch’s theorem, connecting the first cell to the next.
#
# Together with the continuity at $x=0$ (Region I/II boundary), these conditions allow derivation of the dispersion relation.

# %% [markdown]
# 6. Show that the dispersion relation can be written, in the case $ 0 < E < V_0 $:
#
# Using the continuity conditions of the wave function and its derivative at $x=0$ and $x=b$ (from (1)- (3)):
#
# $$
# \psi_I(0)=\psi_{II}(0) \quad\Longrightarrow\quad A + B = C + D,
# $$
#
# $$
# \psi_I'(0)=\psi_{II}'(0) \quad\Longrightarrow\quad \beta(A - B)=i\alpha(C - D).
# $$
#
# $$
# \psi_{II}(b) = \psi_{III}(b) \quad \Longrightarrow \quad
# C e^{i \alpha b} + D e^{-i \alpha b} = e^{i k a} \Bigl( A e^{\beta c} + B e^{-\beta c} \Bigr),
# $$
#
# $$
# \psi_{II}'(b) = \psi_{III}'(b) \quad \Longrightarrow \quad
# i \alpha \big( C e^{i \alpha b} - D e^{-i \alpha b} \big) = e^{i k a} \beta \big( A e^{\beta c} - B e^{-\beta c} \big).
# $$
#
# From the continuity at $x=0$ express $C$ and $D$ in terms of $A$ and $B$:
#
# $$
# C = \frac{1}{2} \Big( (A+B) - i \frac{\beta}{\alpha} (A-B) \Big), \qquad
# D = \frac{1}{2} \Big( (A+B) + i \frac{\beta}{\alpha} (A-B) \Big).
# $$
#
# Substitute these into the expressions at $x=b$. Compute
#
# $$
# C e^{i \alpha b} + D e^{-i \alpha b}
# = \frac{1}{2} \Big( (A+B)(e^{i \alpha b} + e^{-i \alpha b}) - i \frac{\beta}{\alpha} (A-B)(e^{i \alpha b} - e^{-i \alpha b}) \Big).
# $$
#
# Use the trigonometric identities
#
# $$
# e^{i \alpha b} + e^{-i \alpha b} = 2 \cos(\alpha b), \qquad
# e^{i \alpha b} - e^{-i \alpha b} = 2 i \sin(\alpha b),
# $$
#
# and the hyperbolic identities
#
# $$
# e^{\beta c} + e^{-\beta c} = 2 \cosh(\beta c), \qquad
# e^{\beta c} - e^{-\beta c} = 2 \sinh(\beta c).
# $$
#
# Then one obtains
#
# $$
# C e^{i \alpha b} + D e^{-i \alpha b} = (A+B)\cos(\alpha b) + \frac{\beta}{\alpha} (A-B) \sin(\alpha b),
# $$
#
# and
#
# $$
# i \alpha (C e^{i \alpha b} - D e^{-i \alpha b})
# = (A+B) \alpha \sin(\alpha b) - (A-B) \beta \cos(\alpha b).
# $$
#
#
# Hence the homogeneous linear system  at $x=b$ becomes
#
# $$
# (A+B) \cos(\alpha b) + \frac{\beta}{\alpha} (A-B) \sin(\alpha b) = e^{i k a} \big( A e^{\beta c} + B e^{-\beta c} \big),
# $$
#
# $$
# (A+B) \alpha \sin(\alpha b) - (A-B) \beta \cos(\alpha b) = e^{i k a} \beta \big( A e^{\beta c} - B e^{-\beta c} \big).
# $$
# ---
#
# With introduce the abbreviations
# $$
# X=e^{ika},\qquad u=A+B,\qquad v=A-B.
# $$
#
# $$
# \begin{pmatrix}
# \cos(\alpha b)-X\cosh(\beta c) & \dfrac{\beta}{\alpha}\sin(\alpha b)-X\sinh(\beta c)\\[8pt]
# \alpha\sin(\alpha b)-X\beta\sinh(\beta c) & -\beta\cos(\alpha b)+X\beta\cosh(\beta c)
# \end{pmatrix}
# \begin{pmatrix} u\\ v\end{pmatrix}
# = \begin{pmatrix}0\\0\end{pmatrix}.
# $$
#
# For a nontrivial solution, the determinant must vanish:
#
# $$
# \begin{vmatrix}
# \cos(\alpha b)-X\cosh(\beta c) & \dfrac{\beta}{\alpha}\sin(\alpha b)-X\sinh(\beta c)\\[8pt]
# \alpha\sin(\alpha b)-X\beta\sinh(\beta c) & -\beta\cos(\alpha b)+X\beta\cosh(\beta c)
# \end{vmatrix} = 0.
# $$
#
# Expanding the determinant gives
#
# $$
# (\cos\alpha b - X\cosh\beta c)(-\beta\cos\alpha b + X\beta\cosh\beta c)
# -
# \left( \frac{\beta}{\alpha}\sin\alpha b - X\sinh\beta c \right)
# \left( \alpha\sin\alpha b - X\beta\sinh\beta c \right) = 0.
# $$
#
# ---
#
# Simplify and group terms:
#
# $$
# -\beta\cos^2\!\alpha b + 2X\beta\cos\alpha b \cosh\beta c - X^2\beta\cosh^2\!\beta c
# - \frac{\beta}{\alpha}\alpha\sin^2\!\alpha b + X\left(\frac{\beta^2}{\alpha}+\alpha\right)\sin\alpha b\sinh\beta c - X^2\beta\sinh^2\!\beta c = 0.
# $$
#
# $$
# -\beta(\cos^2\!\alpha b + \sin^2\!\alpha b)
# + 2X\beta\cos\alpha b \cosh\beta c
# - X^2\beta(\cosh^2\!\beta c + \sinh^2\!\beta c)
# + X\sin\alpha b\sinh\beta c\left( \frac{\beta^2}{\alpha} + \alpha \right) = 0.
# $$
#
# Since $\cos^2\alpha b + \sin^2\alpha b = 1$, we obtain
#
# $$
# -\beta + 2X\beta\cos\alpha b\cosh\beta c
# - X^2\beta(\cosh^2\!\beta c + \sinh^2\!\beta c)
# + X\sin\alpha b\sinh\beta c\left( \frac{\beta^2}{\alpha} + \alpha \right) = 0.
# $$
#
# ---
#
# Divide by $\beta$ (nonzero)
#
# $$
# -1 + 2X\cos\alpha b\cosh\beta c
# - X^2(\cosh^2\!\beta c + \sinh^2\!\beta c)
# + X\sin\alpha b\sinh\beta c\left( \frac{\beta}{\alpha} + \frac{\alpha}{\beta} \right) = 0.
# $$
#
# ---
# Rearrange as a quadratic in $X$
#
# $$
# (\cosh^2\!\beta c + \sinh^2\!\beta c) X^2
# - \left[ 2\cos\alpha b\cosh\beta c + \left( \frac{\alpha}{\beta} + \frac{\beta}{\alpha} \right)\sin\alpha b\sinh\beta c \right] X
# + 1 = 0.
# $$
#
# Divide through by $X$ to obtain a relation involving $X + X^{-1}$:
#
# $$
# (\cosh^2\!\beta c + \sinh^2\!\beta c)\left(X + X^{-1}\right)
# = 2\cos\alpha b\cosh\beta c + \left( \frac{\alpha}{\beta} + \frac{\beta}{\alpha} \right)\sin\alpha b\sinh\beta c.
# $$
#
# Using the identity $\cosh^2x + \sinh^2x = 2\cosh^2x - 1$, we can simplify further — after straightforward algebra, we obtain
#
# $$
# X + X^{-1} = 2\cos(\alpha b)\cosh(\beta c)
# - \frac{\alpha^2 - \beta^2}{\alpha\beta}\sin(\alpha b)\sinh(\beta c).
# $$
#
# ---
# Express in terms of $\cos(ka)$
#
# Since $X = e^{ika}$, it follows that
#
# $$
# X + X^{-1} = e^{ika} + e^{-ika} = 2\cos(ka).
# $$
#
# Hence, dividing both sides by $2$ gives
#
# $$
# \boxed{
# \cos(ka) = \cos(\alpha b)\cosh(\beta c)
# - \frac{\alpha^2 - \beta^2}{2\alpha\beta}\sin(\alpha b)\sinh(\beta c)
# }
# $$
#
# with
#
# $$
# \alpha = \sqrt{\frac{2mE}{\hbar^2}}, \qquad
# \beta = \sqrt{\frac{2m(V_0 - E)}{\hbar^2}}.
#
# $$
#
# ---
#
# This is the required dispersion relation for the case $0 < E < V_0$, describing the allowed energy bands in the Kronig–Penney model.

# %% [markdown]
# 7. Dispersion relation in the case $V_0 < E$.
#
# For $V_0<E$ the electron is oscillatory in both regions. Define
# $$
# \alpha=\sqrt{\frac{2mE}{\hbar^2}},\qquad
# \kappa=\sqrt{\frac{2m(E-V_0)}{\hbar^2}}.
# $$
#
# **Region I (barrier in the reference cell), $x\in[-c,0[$**, now oscillatory:
# $$
# \psi_I(x)=A e^{i\kappa x}+B e^{-i\kappa x}.
# $$
#
# **Region II (free region), $x\in[0,b[$**:
# $$
# \psi_{II}(x)=C e^{i\alpha x}+D e^{-i\alpha x}.
# $$
#
# **Region III (barrier in the next cell, $x\in[b,a[$)** is obtained by Bloch's theorem:
# $$
# \psi_{III}(x)=e^{ika}\psi_I(x-a)=e^{ika}\big(A e^{i\kappa(x-a)}+B e^{-i\kappa(x-a)}\big).
# $$
#
# - Continuity and derivative continuity at $x=0$ give
# $$
# A+B=C+D,
# $$
# $$
# i\kappa(A-B)=i\alpha(C-D).
# $$
# Hence
# $$
# C=\frac{1}{2}\Big((A+B)-\frac{\kappa}{\alpha}(A-B)\Big),\qquad
# D=\frac{1}{2}\Big((A+B)+\frac{\kappa}{\alpha}(A-B)\Big).
# $$
#
# The factors of $i$ cancel because both sides contain $i$.
#
# - Use the expressions for $C,D$ and evaluate at $x=b$. As before one obtains a homogeneous linear system for
# $$
# u=A+B,\qquad v=A-B,
# $$
# of the form
# $$
# \begin{pmatrix}
# \cos(\alpha b)-X\cos(\kappa c) & \dfrac{\kappa}{\alpha}\sin(\alpha b)-X\sin(\kappa c)\\[8pt]
# \alpha\sin(\alpha b)-X\kappa\sin(\kappa c) & -\kappa\cos(\alpha b)+X\kappa\cos(\kappa c)
# \end{pmatrix}
# \begin{pmatrix} u\\ v\end{pmatrix}=0,
# $$
# where $X=e^{ika}$ and we used the trigonometric identities
# $$
# e^{i\kappa c}+e^{-i\kappa c}=2\cos(\kappa c),\qquad
# e^{i\kappa c}-e^{-i\kappa c}=2i\sin(\kappa c).
# $$
#
#
# A non trivial solution exists if the determinant vanishes. The determinant expansion and algebra follow exactly the same pattern as in the $0<E<V_0$ case, except that every occurrence of $\beta$ and hyperbolic functions is replaced by $i\kappa$ and trigonometric functions. Equivalently, perform the substitution
# $$
# \beta\mapsto i\kappa,\qquad \cosh(\beta c)\mapsto\cos(\kappa c),\qquad \sinh(\beta c)\mapsto i\sin(\kappa c)
# $$
# in the dispersion relation of the $0<E<V_0$ case:
# $$
# \cos(ka)=\cos(\alpha b)\cosh(\beta c)
# -\frac{\alpha^2-\beta^2}{2\alpha\beta}\sin(\alpha b)\sinh(\beta c).
# $$
#
# Using $\beta=i\kappa$ we get
# $$
# \cosh(\beta c)=\cosh(i\kappa c)=\cos(\kappa c),\qquad
# \sinh(\beta c)=\sinh(i\kappa c)=i\sin(\kappa c),
# $$
# and
# $$
# \frac{\alpha^2-\beta^2}{2\alpha\beta}
# =\frac{\alpha^2-(i\kappa)^2}{2\alpha(i\kappa)}
# =\frac{\alpha^2+\kappa^2}{2i\alpha\kappa}.
# $$
# Substituting into the previous formula and cancelling the factor $i$ coming from $\sinh(\beta c)$, one obtains the dispersion relation for $V_0<E$:
# $$
# \boxed{\;
# \cos(ka)=\cos(\alpha b)\cos(\kappa c)
# - \frac{\alpha^2+\kappa^2}{2\alpha\kappa}\sin(\alpha b)\sin(\kappa c)
# \;}
# $$
# with
# $$
# \boxed{\;
# \alpha=\sqrt{\frac{2mE}{\hbar^2}},\qquad
# \kappa=\sqrt{\frac{2m(E-V_0)}{\hbar^2}}.
# \;}
# $$

# %% [markdown]
# ## Energy bands
#
# 8. Using a numerical tool (Python, MATLAB, etc.), plot $\cos(k a)$ as a function of $ E ∈ [0,10]$ eV.
#
# 9. Identify the energy intervals for which $∣\cos(k a)∣ ≤ 1$. These correspond to the allowed bands.
#
# 10. Plot $E(k)−⟨V⟩$ in the first half of the Brillouin zone: $k∈[0,\pi/a]$.
#
# 11. Comment on the shape of the obtained curves, comparing them with the curves of the empty lattice model.
#
# 12. Compare the widths of the first two forbidden bands obtained with those expected in the weakly bound (nearly free) electron model using perturbation theory. Conclude on the importance of the second-order correction in this model.

# %% [markdown]
# 8. Using a numerical tool (Python, MATLAB, etc.), plot $\cos(k a)$ as a function of $ E ∈ [0,10]$ eV.
#
# 9. Identify the energy intervals for which $∣\cos(k a)∣ ≤ 1$. These correspond to the allowed bands.
#
# The function  $\cos(k a)$ comes from solving the Schrödinger equation with a periodic potential, using the Kronig–Penney model.Plotting $\cos(k a)$ vs $E$ helps visualize the allowed and forbidden energy bands in a crystal:
#
# - For $∣\cos(ka)∣ ≤ 1$, there exists a real $k$, meaning electrons can have that energy → allowed band.
#
# - For $∣\cos(ka)∣ > 1$, $k$ is complex → forbidden energy gap.
#
# In the plot, the blue bands indicate the forbidden energy zones for electrons in the crystal for the specified parameters.

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import groupby
from operator import itemgetter

# Constants
hbar = 1.0545718e-34   # Reduced Planck constant [J·s]
m = 9.10938356e-31     # Electron mass [kg]
eV = 1.60218e-19       # 1 eV in Joules

# Kronig-Penney parameters
V0 = 5.0 * eV          # Barrier height [J]
b = 1e-10              # Width of free region [m]
c = 0.5e-10            # Width of barrier [m]
a = b + c              # Lattice period

# Energy range [0,10 eV]
E_eV = np.linspace(0.01, 10, 1000)  # Avoid E=0 for sqrt
E = E_eV * eV

# Initialize cos(ka)
cos_ka = np.zeros_like(E)

# Compute alpha, beta/kappa and cos(ka)
for i, Ei in enumerate(E):
    alpha = np.sqrt(2 * m * Ei) / hbar
    if Ei < V0:
        beta = np.sqrt(2 * m * (V0 - Ei)) / hbar
        cos_ka[i] = (np.cos(alpha * b) * np.cosh(beta * c) 
        - ((alpha**2 - beta**2)/(2 * alpha * beta)) * np.sin(alpha * b) * np.sinh(beta * c))
    elif Ei > V0:
        kappa = np.sqrt(2 * m * (Ei - V0)) / hbar
        cos_ka[i] = (np.cos(alpha * b) * np.cos(kappa * c) 
        - ((alpha**2 + kappa**2) / (2 * alpha * kappa)) * np.sin(alpha * b) * np.sin(kappa * c))
    else:  # Ei == V0, limit case
        cos_ka[i] = np.cos(alpha * b) - 0.5 * alpha * c * np.sin(alpha * b)


# Identify allowed bands (|cos(ka)| <= 1)
allowed = np.abs(cos_ka) <= 1
indices = np.where(allowed)[0]

# Find breaks between consecutive indices
breaks = np.where(np.diff(indices) != 1)[0]

# Split indices into continuous bands
bands = np.split(indices, breaks + 1)

# Convert indices to energy ranges
intervals = [(E_eV[band[0]], E_eV[band[-1]]) for band in bands]

print("Allowed energy bands (eV):")
for start, end in intervals:
    print(f"{start:.3f} - {end:.3f}")


# Find forbidden bands

forbidden_bands = []

# Before the first allowed band
if intervals[0][0] > E_eV[0]:
    forbidden_bands.append((E_eV[0], intervals[0][0]))

# Between allowed bands
for i in range(len(intervals) - 1):
    forbidden_bands.append((intervals[i][1], intervals[i+1][0]))

# After the last allowed band
if intervals[-1][1] < E_eV[-1]:
    forbidden_bands.append((intervals[-1][1], E_eV[-1]))

# Plot

plt.figure(figsize=(8,5))
plt.plot(E_eV, cos_ka, label=r'$\cos(ka)$')
plt.axhline(1, color='r', linestyle='--')
plt.axhline(-1, color='r', linestyle='--')
for (start, end) in forbidden_bands:
    plt.axvspan(start, end, color='blue', alpha=0.1, label='Forbidden band' if start == intervals[0][0] else "")
plt.xlabel('Energy E [eV]')
plt.ylabel(r'$\cos(ka)$')
plt.title('$\cos(ka)$ vs E')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Allowed energy bands (eV):
# 1.610 - 10.000

# %% [markdown]
# 10. Plot $E(k)−⟨V⟩$ in the first half of the Brillouin zone: $k∈[0,\pi/a]$.
#
# The quantity $E(k)−⟨V⟩$ shows the deviation of the electron energy in a periodic potential from the average potential energy. It is important for studying electronic band structures, as it demonstrates how the periodic potential modifies the energy levels of electrons in a crystal and helps visualize key features of the energy dispersion, such as band extrema and gaps. Here, $E(k)$ represents the energy of an electron as a function of the wave vector $k$ in a periodic potential, and $⟨V⟩$ is the average potential energy.
# $$
# \langle V \rangle = \frac{1}{a} \int_0^a V(x) \, dx
# $$
#
# In the case of rectangular barrier
# $$
# \langle V \rangle = \frac{1}{a} \int_0^a V(x)\, dx
# = \frac{1}{a} \left[ \int_0^c V_0 \, dx + \int_c^a 0 \, dx \right]
# = \frac{V_0 \, c}{a}
# $$

# %% [markdown]
# To display the full first Brillouin zone, we mirror the allowed $k$ values to negative values. This extends the plot from $k∈[0,\pi/a]$ to $k∈[−\pi/a,pi/a]$, allowing visualization of the complete zone structure.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
hbar = 1.0545718e-34   # Reduced Planck constant [J·s]
m = 9.10938356e-31     # Electron mass [kg]
eV = 1.60218e-19       # 1 eV in Joules

# Kronig-Penney parameters
V0 = 5.0 * eV          # Barrier height [J]
b = 1e-10              # Width of free region [m]
c = 0.5e-10            # Width of barrier [m]
a = b + c              # Lattice period

# Energy range
E_eV = np.linspace(0.01, 50, 5000)
E = E_eV * eV

# Initialize arrays
cos_ka = np.zeros_like(E)

# Compute cos(ka)
for i, Ei in enumerate(E):
    alpha = np.sqrt(2*m*Ei)/hbar
    if Ei < V0:
        beta = np.sqrt(2*m*(V0 - Ei))/hbar
        cos_ka[i] = (np.cos(alpha*b)*np.cosh(beta*c) 
                     - ((alpha**2 - beta**2)/(2*alpha*beta))*np.sin(alpha*b)*np.sinh(beta*c))
    elif Ei > V0:
        kappa = np.sqrt(2*m*(Ei - V0))/hbar
        cos_ka[i] = (np.cos(alpha*b)*np.cos(kappa*c) 
                     - ((alpha**2 + kappa**2)/(2*alpha*kappa))*np.sin(alpha*b)*np.sin(kappa*c))
    else:  # Ei == V0
        cos_ka[i] = np.cos(alpha*b) - 0.5*alpha*c*np.sin(alpha*b)

# Allowed bands: |cos(ka)| <= 1
allowed = np.abs(cos_ka) <= 1
E_allowed = E[allowed]
cos_ka_allowed = cos_ka[allowed]

# Compute k for allowed energies
k_allowed = np.arccos(cos_ka_allowed)/a  # First Brillouin zone: k ∈ [0, π/a]

# Average potential
V_avg = V0 * (c/a)

# Plot E(k) - <V>
plt.figure(figsize=(8,5))
plt.plot(k_allowed, E_allowed/eV - V_avg/eV, '.', markersize=1)
plt.plot(-k_allowed, E_allowed/eV - V_avg/eV, '.', markersize=1)  # Add to show the full first Brillouin zone


plt.axvline(np.pi/a, color='r', linestyle='--', label='First Brillouin zone edge (π/a)')
plt.axvline(-np.pi/a, color='r', linestyle='--', label='First Brillouin zone edge (π/a)') # Add negative k values so the plot covers the entire first Brillouin zone (k ∈ [-π/a, π/a])


plt.xlabel('k [1/m]')
plt.ylabel('E(k) - <V> [eV]')
plt.title('Energy bands in the first Brillouin zone')
plt.grid(True)
plt.show()

# %% [markdown]
# The next plot shows the energy bands of an electron in a one-dimensional periodic potential (Kronig-Penney model) across multiple Brillouin zones. Allowed energies, where $|\cos(ka)| \le 1$, are plotted as points, while forbidden regions (band gaps) appear as empty spaces.
#
# To display the full first Brillouin zone, the allowed wave vectors $k$ are mirrored to negative values ($k \in [-\pi/a, \pi/a]$). The plot is then extended by shifting $k$ by multiples of the reciprocal lattice vector $2\pi/a$, producing a symmetric extended-zone diagram that shows $n$ Brillouin zones on each side of $k=0$.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
hbar = 1.0545718e-34   # Reduced Planck constant [J·s]
m = 9.10938356e-31     # Electron mass [kg]
eV = 1.60218e-19       # 1 eV in Joules

# Kronig-Penney parameters
V0 = 5.0 * eV          # Barrier height [J]
b = 1e-10              # Width of free region [m]
c = 0.5e-10            # Width of barrier [m]
a = b + c              # Lattice period

# Energy range
E_eV = np.linspace(0.01, 100, 5000)
E = E_eV * eV

# Compute cos(ka)
cos_ka = np.zeros_like(E)
for i, Ei in enumerate(E):
    alpha = np.sqrt(2*m*Ei)/hbar
    if Ei < V0:
        beta = np.sqrt(2*m*(V0 - Ei))/hbar
        cos_ka[i] = np.cos(alpha*b)*np.cosh(beta*c) - ((alpha**2 - beta**2)/(2*alpha*beta))*np.sin(alpha*b)*np.sinh(beta*c)
    elif Ei > V0:
        kappa = np.sqrt(2*m*(Ei - V0))/hbar
        cos_ka[i] = np.cos(alpha*b)*np.cos(kappa*c) - ((alpha**2 + kappa**2)/(2*alpha*kappa))*np.sin(alpha*b)*np.sin(kappa*c)
    else:  # Ei == V0
        cos_ka[i] = np.cos(alpha*b) - 0.5*alpha*c*np.sin(alpha*b)

# Allowed energies: |cos(ka)| <= 1
allowed = np.abs(cos_ka) <= 1
E_allowed = E[allowed]
cos_ka_allowed = cos_ka[allowed]

# Compute k for allowed energies in first Brillouin zone
k_allowed = np.arccos(cos_ka_allowed)/a

# Mirror for negative k (to show symmetry)
k_vals = np.concatenate([-k_allowed[::-1], k_allowed])
E_vals = np.concatenate([E_allowed[::-1], E_allowed])

# Extend to multiple zones
num_zones = 3  # Number of Brillouin zones
k_all = []
E_all = []

# Average potential
V_avg = V0 * (c/a)

for n in range(-num_zones+1, num_zones):
    k_shifted = k_vals + 2*n*np.pi/a
    k_all.append(k_shifted)
    E_all.append(E_vals)

k_all = np.concatenate(k_all)
E_all = np.concatenate(E_all)

# Plot the energy bands
plt.figure(figsize=(10,6))
plt.plot(k_all, E_all/eV - V_avg/eV, '.', markersize=1, color='b')
for n in range(-num_zones, num_zones+1):
    plt.axvline(n*np.pi/a, color='r', linestyle='--', alpha=0.5)  # Brillouin zone boundaries
plt.xlabel('k [1/m]')
plt.ylabel('Energy [eV]')
plt.title('Kronig-Penney Model: Crystal Band Structure')
plt.grid(True)
plt.show()

# %% [markdown]
# 11. Comment on the shape of the obtained curves, comparing them with the curves of the empty lattice model.
#
# In the empty lattice model, the parabolic curves of each repeated zone intersect without gaps, forming a series of overlapping free-electron parabolas. In contrast, in the Kronig-Penney model, the intersections are replaced by energy gaps, reflecting the influence of the potential.

# %% [markdown]
# 12. Compare the widths of the first two forbidden bands obtained with those expected in the weakly bound (nearly free) electron model using perturbation theory. Conclude on the importance of the second-order correction in this model.
#
#
# **1. Nearly free electron model**
# - Consider an electron moving in a weak periodic potential $V(x)$ with period $a$.
# - In the absence of the potential (empty lattice), the electron energy is simply:
# $$
# E_0(k) = \frac{\hbar^2 k^2}{2m}.
# $$
# - The periodic potential perturbs this free-electron energy, opening gaps at the Brillouin zone edges where Bragg reflection occurs.
#
# **2. Perturbation theory approach**
# The potential can be written as a Fourier series:
# $$
# V(x) = \sum_G V_G e^{i G x}, \quad G = \frac{2\pi n}{a}, \ n = 0, \pm 1, \pm 2, \dots
# $$
#
# At the zone boundary $k = \pm G/2$, two free-electron states are degenerate:
# $$
# E_0(k) = E_0(k - G).
# $$
#
# Using degenerate first-order perturbation theory, the energy gap at this zone boundary is:
# $$
# \Delta E_G = 2 |V_G|,
# $$
# where $V_G$ is the Fourier coefficient of the potential corresponding to the reciprocal lattice vector $G$.
#
# So:
#
# - First Brillouin zone edge ($k = \pi/a$): $\Delta E_1 \approx 2|V_1|$
# - Second Brillouin zone edge ($k = 2\pi/a$): $\Delta E_2 \approx 2|V_2|$
#
# Observation: $|V_2| < |V_1|$ for most potentials, so the second gap is smaller than the first.
#
# **3. Second-order corrections**
# - First-order perturbation theory gives a rough estimate of the gap.
# - For higher-energy bands or stronger potentials, second-order corrections are important:
# $$
# E^{(2)} = \sum_{n \neq m} \frac{|\langle n | V | m \rangle|^2}{E_m^{(0)} - E_n^{(0)}}.
# $$
#
# These corrections increase the accuracy of predicted gap widths, especially for the second and higher forbidden bands.
#
# ---
#
# So, the theory predicts gaps at Brillouin zone boundaries, with width proportional to the Fourier coefficients of the potential.
#
# The first gap is largest, higher gaps are smaller.
#
# Your Kronig-Penney numerical results should qualitatively match this: the first forbidden band is the widest, the second smaller, and higher gaps shrink further.
#
# Second-order corrections refine the widths, especially for the second gap and beyond.

# %% [markdown]
# ## Application of the Kronig-Penney Model
#
# **Understanding Electronic Band Structure**
#
# - The model explains how a periodic potential in a crystal lattice splits the free-electron energy spectrum into allowed bands and forbidden gaps (band gaps).
#
# - It provides a qualitative and semi-quantitative insight into why solids have conduction and valence bands.
#
# **Prediction of Conductors, Semiconductors, and Insulators**
#
# By showing the existence and size of energy gaps, the model helps understand why some materials conduct electricity (small or no gap) and others do not (large gap).
#
# **Optical Properties of Solids**
#
# - The position and size of forbidden gaps determine the absorption and emission of photons in semiconductors and insulators.
#
# - This is important for optoelectronic devices such as LEDs and solar cells.
#
# **Basis for More Advanced Models**
#
# - Simplified one-dimensional model, but it forms the basis for more realistic three-dimensional band structure calculations.
#
# - Helps develop concepts like effective mass, Bloch functions, and zone folding.
#
# **Teaching Tool in Solid-State Physics**
#
# Its analytic solvability makes it an excellent pedagogical tool for understanding band formation without full numerical simulations.
#
# **Designing Superlattices and Quantum Wells**
#
# The model can be adapted to study engineered periodic potentials, such as semiconductor superlattices or quantum wells, to predict miniband formation and tunneling properties.

# %% [markdown]
# **Superlattices (Quantum wire)** - A superlattice is a periodic structure of layers of two (or more) materials. Typically, the thickness of one layer is several nanometers. It can also refer to a lower-dimensional structure such as an array of quantum dots or quantum wells.
#
# <div style="text-align: center;">
# <img src="GaAs-AlAs_SL.png" alt="GaAs-AlAs_SL" width="30%"  />
#
# Fig.2. GaAs/AlAs superlattice and potential profile of conduction and valence bands along the growth direction (z).
# </div>

# %% [markdown]
# **Quantum Cascade Lasers (QCLs)**
#
# Superlattices form the active region in QCLs, where electrons tunnel through a series of quantum wells and barriers, emitting photons at each step.
#
# → Enables mid- and far-infrared laser sources with tunable wavelengths.
#
# **High-Electron-Mobility Transistors (HEMTs)**
#
# In AlGaAs/GaAs superlattices, electrons are confined in a two-dimensional electron gas (2DEG) within quantum wells, leading to very high carrier mobility.
#
# → Used in high-frequency microwave and low-noise amplifiers.
#
# **Infrared Detectors and Sensors**
#
# Superlattice infrared photodetectors (like InAs/GaSb) exploit interband or intersubband transitions between minibands to detect mid-IR and long-wave IR light.
#
# → Applications in thermal imaging, night vision, and space sensing.
#
# **Optoelectronic Modulators and Filters**
#
# Periodic minibands allow selective transmission of electrons or photons, making superlattices useful in electro-optic modulators and quantum well infrared filters.

# %% [markdown]
# | **Superlattice System** | **Type** | **Applications** | **Notes** |
# |--------------------------|----------|------------------|-----------|
# | **GaAs/AlAs** | III–V semiconductors | Lasers, photodetectors, HEMTs | Classic example of the Kronig–Penney model; demonstrates well-defined minibands and strong control over electronic properties. |
# | **GaAs/AlGaAs** | III–V semiconductors | Quantum cascade lasers, THz sources | Tunable band offsets and adjustable barrier widths allow precise miniband engineering and high-frequency response. |
# | **Si/Ge** | IV semiconductors | Thermoelectric devices, IR detectors | Strain-modified band structures enhance carrier mobility and reduce lattice thermal conductivity. |
# | **Graphene/hBN** | 2D van der Waals materials | Quantum Hall effect, moiré superlattices, twistronics | Moiré pattern forms minibands; enables study of correlated electron effects and tunable electronic phases. |
# | **GaN/AlGaN** | Wide-bandgap nitrides | Blue/UV LEDs, high-power and high-frequency transistors | Strong confinement and polarization effects increase carrier density and improve efficiency in optoelectronic devices. |

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
hbar = 1.0545718e-34   # J.s
m = 9.10938356e-31     # kg
eV = 1.60218e-19       # 1 eV in Joules

# Quantum well parameters
V0 = 0.5 * eV       # Barrier height [J]
b = 5e-10           # Well width [m]
c = 2e-10           # Barrier width [m]
a = b + c           # Superlattice period
N_wells = 5         # Number of wells

# Discrete energy levels in a single well (infinite well approx)
n_levels = 3
E_levels = [(n*np.pi*hbar)**2/(2*m*b**2) for n in range(1, n_levels+1)]

# Tunneling splitting: approximate miniband width
tunneling_factor = np.exp(-V0*c/hbar*np.sqrt(2*m))  # crude approximation
miniband_widths = [0.1*E*tunneling_factor for E in E_levels]  # scaled widths

# Plot minibands
plt.figure(figsize=(8,5))

for i, E0 in enumerate(E_levels):
    # Generate miniband points
    k = np.linspace(-np.pi/a, np.pi/a, 200)
    E_min = E0 - miniband_widths[i]/2
    E_max = E0 + miniband_widths[i]/2
    plt.fill_between(k, E_min/eV, E_max/eV, alpha=0.4, label=f'Miniband {i+1}')

plt.xlabel('k [1/m]')
plt.ylabel('Energy [eV]')
plt.title(f'Minibands in a {N_wells}-well Quantum Superlattice')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# This plot shows the band structure of a quantum well superlattice: the blue curves represent the allowed electron energies (minibands) as a function of the wave vector $k$ within the first Brillouin zone, illustrating how the electron energy depends on momentum due to the periodic potential, while the horizontal red shaded regions indicate forbidden energy intervals (band gaps) where electrons cannot exist, highlighting the separation between minibands caused by Bragg reflection at the zone edges.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
hbar = 1.0545718e-34        # Reduced Planck constant [J·s]
eV = 1.60218e-19            # 1 eV in Joules

# Quantum well superlattice parameters
m_well = 0.067 * 9.10938356e-31     # Effective mass in well (GaAs)
m_barrier = 0.091 * 9.10938356e-31  # Effective mass in barrier (AlGaAs)
V0 = 0.3 * eV                        # Barrier height [J]
b = 5e-9                             # Well width [m]
c = 2e-9                             # Barrier width [m]
a = b + c                             # Superlattice period

# Energy range (high resolution)
E_eV = np.linspace(0.01, 3.5, 10000)  # eV
E = E_eV * eV

# Compute Kronig-Penney function
cos_ka = np.zeros_like(E)
for i, Ei in enumerate(E):
    alpha = np.sqrt(2*m_well*Ei)/hbar
    if Ei < V0:
        beta = np.sqrt(2*m_barrier*(V0 - Ei))/hbar
        cos_ka[i] = np.cos(alpha*b)*np.cosh(beta*c) - ((alpha**2 - beta**2)/(2*alpha*beta))*np.sin(alpha*b)*np.sinh(beta*c)
    else:
        kappa = np.sqrt(2*m_barrier*(Ei - V0))/hbar
        cos_ka[i] = np.cos(alpha*b)*np.cos(kappa*c) - ((alpha**2 + kappa**2)/(2*alpha*kappa))*np.sin(alpha*b)*np.sin(kappa*c)

# Allowed energies: |cos(ka)| <= 1
allowed = np.abs(cos_ka) <= 1
E_allowed = E[allowed]
cos_ka_allowed = cos_ka[allowed]

if len(E_allowed) == 0:
    raise ValueError("No allowed energies found. Check V0, b, c, or energy range.")

# Compute k values
k_allowed = np.arccos(cos_ka_allowed)/a
# Mirror negative k for full first Brillouin zone
k_vals = np.concatenate([-k_allowed[::-1], k_allowed])
E_vals = np.concatenate([E_allowed[::-1], E_allowed])

# Average potential
V_avg = V0 * (c/a)

# Split allowed energies into minibands (to detect forbidden gaps)
jump_threshold = 1e-3 * eV
bands = []
band = [E_allowed[0]]
for i in range(1, len(E_allowed)):
    if E_allowed[i] - E_allowed[i-1] < jump_threshold:
        band.append(E_allowed[i])
    else:
        bands.append(band)
        band = [E_allowed[i]]
bands.append(band)

# Plot
plt.figure(figsize=(10,6))

# Plot forbidden zones as shaded areas
for i in range(len(bands)-1):
    gap_bottom = bands[i][-1]/eV - V_avg/eV
    gap_top = bands[i+1][0]/eV - V_avg/eV
    plt.fill_between([-np.pi/a, np.pi/a], gap_bottom, gap_top, color='red', alpha=0.3)

# Plot minibands as blue curves
for band in bands:
    k_band = np.linspace(-np.pi/a, np.pi/a, len(band))
    plt.plot(k_band, np.array(band)/eV - V_avg/eV, color='b', lw=2)

# Brillouin zone edges
plt.axvline(-np.pi/a, color='k', linestyle='--', alpha=0.5)
plt.axvline(np.pi/a, color='k', linestyle='--', alpha=0.5)

plt.xlabel('k [1/m]')
plt.ylabel('E(k) - <V> [eV]')
plt.title('Quantum Well Superlattice: Minibands and Forbidden Zones')
plt.grid(True)
plt.show()

# %% [markdown]
# This plot demonstrates the energy band structure of an electron in a quantum well superlattice. The blue points represent the allowed energies (minibands) as a function of the wave vector $k$ within the first Brillouin zone, showing how the electron’s energy varies with momentum due to the periodic arrangement of wells and barriers. The red dashed vertical lines mark the edges of the Brillouin zone ($k=±\pi/a$), where band gaps can form due to Bragg reflection. Although forbidden zones are not explicitly shaded here, the gaps between clusters of blue points indicate energy intervals where electrons cannot exist, highlighting the effect of the periodic potential on the electron states.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
hbar = 1.0545718e-34        # Reduced Planck constant [J·s]
eV = 1.60218e-19            # 1 eV in Joules

# Quantum well parameters
m_well = 0.067 * 9.10938356e-31
m_barrier = 0.091 * 9.10938356e-31
V0 = 0.3 * eV
b = 5e-9
c = 2e-9
a = b + c

# Energy range
E_eV = np.linspace(0.01, 1.5, 10000)
E = E_eV * eV

# Compute cos(ka)
cos_ka = np.zeros_like(E)
for i, Ei in enumerate(E):
    alpha = np.sqrt(2*m_well*Ei)/hbar
    if Ei < V0:
        beta = np.sqrt(2*m_barrier*(V0 - Ei))/hbar
        cos_ka[i] = np.cos(alpha*b)*np.cosh(beta*c) - ((alpha**2 - beta**2)/(2*alpha*beta))*np.sin(alpha*b)*np.sinh(beta*c)
    else:
        kappa = np.sqrt(2*m_barrier*(Ei - V0))/hbar
        cos_ka[i] = np.cos(alpha*b)*np.cos(kappa*c) - ((alpha**2 + kappa**2)/(2*alpha*kappa))*np.sin(alpha*b)*np.sin(kappa*c)

# Allowed energies
allowed = np.abs(cos_ka) <= 1
E_allowed = E[allowed]
cos_ka_allowed = cos_ka[allowed]

# Compute k
k_allowed = np.arccos(cos_ka_allowed)/a

# Mirror for negative k
k_vals = np.concatenate([-k_allowed[::-1], k_allowed])
E_vals = np.concatenate([E_allowed[::-1], E_allowed])

# Average potential
V_avg = V0 * (c/a)

# Plot
plt.figure(figsize=(10,6))
plt.plot(k_vals, E_vals/eV - V_avg/eV, '.', markersize=1, color='b')

# Brillouin zone edges
plt.axvline(-np.pi/a, color='r', linestyle='--', alpha=0.5)
plt.axvline(np.pi/a, color='r', linestyle='--', alpha=0.5)

plt.xlabel('k [1/m]')
plt.ylabel('E(k) - <V> [eV]')
plt.title('Quantum Well Superlattice: Minibands and Forbidden Zones')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
hbar = 1.0545718e-34        # Reduced Planck constant [J·s]
eV = 1.60218e-19            # 1 eV in Joules

# Superlattice parameters
m_well = 0.067 * 9.10938356e-31     # GaAs
m_barrier = 0.091 * 9.10938356e-31  # AlGaAs
V0 = 0.3 * eV                        # Barrier height
b = 5e-9                             # Well width
c = 2e-9                             # Barrier width
a = b + c                             # Superlattice period

# Electron density (for occupation illustration)
n_electrons = 2  # number of electrons per unit cell (simplified)

# Energy range
E_eV = np.linspace(0.01, 1.5, 10000)
E = E_eV * eV

# Kronig-Penney calculation
cos_ka = np.zeros_like(E)
for i, Ei in enumerate(E):
    alpha = np.sqrt(2*m_well*Ei)/hbar
    if Ei < V0:
        beta = np.sqrt(2*m_barrier*(V0 - Ei))/hbar
        cos_ka[i] = np.cos(alpha*b)*np.cosh(beta*c) - ((alpha**2 - beta**2)/(2*alpha*beta))*np.sin(alpha*b)*np.sinh(beta*c)
    else:
        kappa = np.sqrt(2*m_barrier*(Ei - V0))/hbar
        cos_ka[i] = np.cos(alpha*b)*np.cos(kappa*c) - ((alpha**2 + kappa**2)/(2*alpha*kappa))*np.sin(alpha*b)*np.sin(kappa*c)

# Allowed energies
allowed = np.abs(cos_ka) <= 1
E_allowed = E[allowed]

# Compute k for allowed energies
k_allowed = np.arccos(cos_ka[allowed])/a
k_vals = np.concatenate([-k_allowed[::-1], k_allowed])
E_vals = np.concatenate([E_allowed[::-1], E_allowed])

# Split allowed energies into minibands
jump_threshold = 1e-4 * eV
bands = []
band = [E_allowed[0]]
for i in range(1, len(E_allowed)):
    if E_allowed[i] - E_allowed[i-1] < jump_threshold:
        band.append(E_allowed[i])
    else:
        bands.append(band)
        band = [E_allowed[i]]
bands.append(band)

# Determine Fermi energy (simple illustration: fill lowest minibands)
E_f = 0
electrons_counted = 0
for band in bands:
    electrons_counted += len(band)  # Simplified: 1 state per energy point
    if electrons_counted >= n_electrons:
        E_f = band[-1]/eV
        break

# Average potential for reference
V_avg = V0 * (c/a)

# Plot
plt.figure(figsize=(10,6))

# Plot forbidden zones
for i in range(len(bands)-1):
    gap_bottom = bands[i][-1]/eV - V_avg/eV
    gap_top = bands[i+1][0]/eV - V_avg/eV
    plt.fill_between([-np.pi/a, np.pi/a], gap_bottom, gap_top, color='red', alpha=0.2)

# Plot allowed minibands
for band in bands:
    k_band = np.linspace(-np.pi/a, np.pi/a, len(band))
    plt.plot(k_band, np.array(band)/eV - V_avg/eV, color='b', lw=2)

# Plot Fermi energy line
plt.axhline(E_f - V_avg/eV, color='g', linestyle='--', label=f'Fermi level ~ {E_f:.2f} eV')

# Brillouin zone edges
plt.axvline(-np.pi/a, color='k', linestyle='--', alpha=0.5)
plt.axvline(np.pi/a, color='k', linestyle='--', alpha=0.5)

plt.xlabel('k [1/m]')
plt.ylabel('E(k) - <V> [eV]')
plt.title('Superlattice: Minibands, Forbidden Zones, and Electron Occupation')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
hbar = 1.0545718e-34   # Reduced Planck constant [J·s]
eV = 1.60218e-19       # 1 eV in Joules

# Superlattice parameters
V0_e = 0.3 * eV   # Conduction band barrier height
V0_h = 0.2 * eV   # Valence band barrier height (for holes)
b = 5e-9          # Well width
c = 2e-9          # Barrier width
a = b + c         # Lattice period

# Effective masses
m0 = 9.10938356e-31
m_e_well = 0.067 * m0
m_e_barrier = 0.091 * m0
m_h_well = 0.50 * m0
m_h_barrier = 0.60 * m0

# Energy ranges
E_e = np.linspace(0.01, 1.0, 5000) * eV
E_h = np.linspace(0.01, 0.5, 5000) * eV

def cos_ka(E, m_well, m_barrier, V0):
    coska = np.zeros_like(E)
    for i, Ei in enumerate(E):
        alpha = np.sqrt(2*m_well*Ei)/hbar
        if Ei < V0:
            beta = np.sqrt(2*m_barrier*(V0 - Ei))/hbar
            coska[i] = np.cos(alpha*b)*np.cosh(beta*c) - ((alpha**2 - beta**2)/(2*alpha*beta))*np.sin(alpha*b)*np.sinh(beta*c)
        else:
            kappa = np.sqrt(2*m_barrier*(Ei - V0))/hbar
            coska[i] = np.cos(alpha*b)*np.cos(kappa*c) - ((alpha**2 + kappa**2)/(2*alpha*kappa))*np.sin(alpha*b)*np.sin(kappa*c)
    return coska

# Electron minibands
coska_e = cos_ka(E_e, m_e_well, m_e_barrier, V0_e)
allowed_e = np.abs(coska_e) <= 1
E_allowed_e = E_e[allowed_e]
k_e = np.arccos(coska_e[allowed_e]) / a

# Hole minibands
coska_h = cos_ka(E_h, m_h_well, m_h_barrier, V0_h)
allowed_h = np.abs(coska_h) <= 1
E_allowed_h = E_h[allowed_h]
k_h = np.arccos(coska_h[allowed_h]) / a

# Mirror negative k
k_vals_e = np.concatenate([-k_e[::-1], k_e])
E_vals_e = np.concatenate([E_allowed_e[::-1], E_allowed_e])
k_vals_h = np.concatenate([-k_h[::-1], k_h])
E_vals_h = np.concatenate([E_allowed_h[::-1], E_allowed_h])

# Plot
plt.figure(figsize=(10,6))
plt.plot(k_vals_e, E_vals_e/eV, '.', markersize=1, label='Electrons', color='b')
plt.plot(k_vals_h, -E_vals_h/eV, '.', markersize=1, label='Holes', color='r')  # negative for valence band

# Brillouin zone edges
plt.axvline(-np.pi/a, color='k', linestyle='--', alpha=0.5)
plt.axvline(np.pi/a, color='k', linestyle='--', alpha=0.5)

plt.xlabel('k [1/m]')
plt.ylabel('Energy [eV]')
plt.title('GaAs/AlAs Superlattice: Electron and Hole Minibands')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
hbar = 1.0545718e-34   # Reduced Planck constant [J·s]
eV = 1.60218e-19       # 1 eV in Joules

# Superlattice parameters
V0_e = 0.3 * eV   # Conduction band barrier height
V0_h = 0.2 * eV   # Valence band barrier height (for holes)
b = 5e-9          # Well width
c = 2e-9          # Barrier width
a = b + c         # Lattice period

# Effective masses
m0 = 9.10938356e-31
m_e_well = 0.067 * m0
m_e_barrier = 0.091 * m0
m_h_well = 0.50 * m0
m_h_barrier = 0.60 * m0

# Energy ranges
E_e = np.linspace(0.01, 1.0, 5000) * eV
E_h = np.linspace(0.01, 0.5, 5000) * eV

def cos_ka(E, m_well, m_barrier, V0):
    coska = np.zeros_like(E)
    for i, Ei in enumerate(E):
        alpha = np.sqrt(2*m_well*Ei)/hbar
        if Ei < V0:
            beta = np.sqrt(2*m_barrier*(V0 - Ei))/hbar
            coska[i] = np.cos(alpha*b)*np.cosh(beta*c) - ((alpha**2 - beta**2)/(2*alpha*beta))*np.sin(alpha*b)*np.sinh(beta*c)
        else:
            kappa = np.sqrt(2*m_barrier*(Ei - V0))/hbar
            coska[i] = np.cos(alpha*b)*np.cos(kappa*c) - ((alpha**2 + kappa**2)/(2*alpha*kappa))*np.sin(alpha*b)*np.sin(kappa*c)
    return coska

# Electron minibands
coska_e = cos_ka(E_e, m_e_well, m_e_barrier, V0_e)
allowed_e = np.abs(coska_e) <= 1
forbidden_e = np.abs(coska_e) > 1
E_allowed_e = E_e[allowed_e]
k_e = np.arccos(coska_e[allowed_e]) / a

# Hole minibands
coska_h = cos_ka(E_h, m_h_well, m_h_barrier, V0_h)
allowed_h = np.abs(coska_h) <= 1
forbidden_h = np.abs(coska_h) > 1
E_allowed_h = E_h[allowed_h]
k_h = np.arccos(coska_h[allowed_h]) / a

# Mirror negative k
k_vals_e = np.concatenate([-k_e[::-1], k_e])
E_vals_e = np.concatenate([E_allowed_e[::-1], E_allowed_e])
k_vals_h = np.concatenate([-k_h[::-1], k_h])
E_vals_h = np.concatenate([E_allowed_h[::-1], E_allowed_h])

# Plot
plt.figure(figsize=(10,6))

# Allowed minibands
plt.plot(k_vals_e, E_vals_e/eV, '.', markersize=1, label='Electrons', color='b')
plt.plot(k_vals_h, -E_vals_h/eV, '.', markersize=1, label='Holes', color='r')  # negative for valence band

# Forbidden zones for electrons
plt.fill_betweenx(E_e/eV, -np.pi/a, np.pi/a, where=forbidden_e, color='blue', alpha=0.1)

# Forbidden zones for holes
plt.fill_betweenx(-E_h/eV, -np.pi/a, np.pi/a, where=forbidden_h, color='red', alpha=0.1)

# Brillouin zone edges
plt.axvline(-np.pi/a, color='k', linestyle='--', alpha=0.5)
plt.axvline(np.pi/a, color='k', linestyle='--', alpha=0.5)

plt.xlabel('k [1/m]')
plt.ylabel('Energy [eV]')
plt.title('GaAs/AlAs Superlattice: Electron and Hole Minibands with Forbidden Zones')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
hbar = 1.0545718e-34   # Reduced Planck constant [J·s]
eV = 1.60218e-19       # 1 eV in Joules

# Superlattice parameters
V0_e = 0.3 * eV   # Conduction band barrier height
V0_h = 0.2 * eV   # Valence band barrier height (for holes)
b = 5e-9          # Well width
c = 2e-9          # Barrier width
a = b + c         # Lattice period

# Effective masses
m0 = 9.10938356e-31
m_e_well = 0.067 * m0
m_e_barrier = 0.091 * m0
m_h_well = 0.50 * m0
m_h_barrier = 0.60 * m0

# Energy ranges
E_e = np.linspace(0.01, 1.0, 5000) * eV
E_h = np.linspace(0.01, 0.5, 5000) * eV

def cos_ka(E, m_well, m_barrier, V0):
    coska = np.zeros_like(E)
    for i, Ei in enumerate(E):
        alpha = np.sqrt(2*m_well*Ei)/hbar
        if Ei < V0:
            beta = np.sqrt(2*m_barrier*(V0 - Ei))/hbar
            coska[i] = np.cos(alpha*b)*np.cosh(beta*c) - ((alpha**2 - beta**2)/(2*alpha*beta))*np.sin(alpha*b)*np.sinh(beta*c)
        else:
            kappa = np.sqrt(2*m_barrier*(Ei - V0))/hbar
            coska[i] = np.cos(alpha*b)*np.cos(kappa*c) - ((alpha**2 + kappa**2)/(2*alpha*kappa))*np.sin(alpha*b)*np.sin(kappa*c)
    return coska

# Electron minibands
coska_e = cos_ka(E_e, m_e_well, m_e_barrier, V0_e)
allowed_e = np.abs(coska_e) <= 1
forbidden_e = np.abs(coska_e) > 1
E_allowed_e = E_e[allowed_e]
k_e = np.arccos(coska_e[allowed_e]) / a

# Hole minibands
coska_h = cos_ka(E_h, m_h_well, m_h_barrier, V0_h)
allowed_h = np.abs(coska_h) <= 1
forbidden_h = np.abs(coska_h) > 1
E_allowed_h = E_h[allowed_h]
k_h = np.arccos(coska_h[allowed_h]) / a

# Mirror negative k
k_vals_e = np.concatenate([-k_e[::-1], k_e])
E_vals_e = np.concatenate([E_allowed_e[::-1], E_allowed_e])
k_vals_h = np.concatenate([-k_h[::-1], k_h])
E_vals_h = np.concatenate([E_allowed_h[::-1], E_allowed_h])

# Plot
plt.figure(figsize=(10,6))

# Allowed minibands
plt.plot(k_vals_e, E_vals_e/eV, '.', markersize=1, label='Electrons', color='b')
plt.plot(k_vals_h, -E_vals_h/eV, '.', markersize=1, label='Holes', color='r')  # negative for valence band

# Forbidden zones for electrons
plt.fill_betweenx(E_e/eV, -np.pi/a, np.pi/a, where=forbidden_e, color='blue', alpha=0.1)

# Forbidden zones for holes
plt.fill_betweenx(-E_h/eV, -np.pi/a, np.pi/a, where=forbidden_h, color='red', alpha=0.1)

# Brillouin zone edges for multiple zones (n = -2, -1, 0, 1, 2)
n_zones = 2
for n in range(-n_zones, n_zones + 1):
    plt.axvline(n*np.pi/a, color='k', linestyle='--', alpha=0.5)

plt.xlabel('k [1/m]')
plt.ylabel('Energy [eV]')
plt.title('GaAs/AlAs Superlattice: Electron and Hole Minibands with Multiple Brillouin Zones')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
hbar = 1.0545718e-34
eV = 1.60218e-19

# Superlattice parameters
V0_e = 0.3 * eV
V0_h = 0.2 * eV
b = 5e-9
c = 2e-9
a = b + c

# Effective masses
m0 = 9.10938356e-31
m_e_well = 0.067 * m0
m_e_barrier = 0.091 * m0
m_h_well = 0.50 * m0
m_h_barrier = 0.60 * m0

# Energy ranges
E_e = np.linspace(0.01, 1.0, 5000) * eV
E_h = np.linspace(0.01, 0.5, 5000) * eV

def cos_ka(E, m_well, m_barrier, V0):
    coska = np.zeros_like(E)
    for i, Ei in enumerate(E):
        alpha = np.sqrt(2*m_well*Ei)/hbar
        if Ei < V0:
            beta = np.sqrt(2*m_barrier*(V0 - Ei))/hbar
            coska[i] = np.cos(alpha*b)*np.cosh(beta*c) - ((alpha**2 - beta**2)/(2*alpha*beta))*np.sin(alpha*b)*np.sinh(beta*c)
        else:
            kappa = np.sqrt(2*m_barrier*(Ei - V0))/hbar
            coska[i] = np.cos(alpha*b)*np.cos(kappa*c) - ((alpha**2 + kappa**2)/(2*alpha*kappa))*np.sin(alpha*b)*np.sin(kappa*c)
    return coska

# Electron minibands
coska_e = cos_ka(E_e, m_e_well, m_e_barrier, V0_e)
allowed_e = np.abs(coska_e) <= 1
E_allowed_e = E_e[allowed_e]
k_e = np.arccos(coska_e[allowed_e]) / a

# Hole minibands
coska_h = cos_ka(E_h, m_h_well, m_h_barrier, V0_h)
allowed_h = np.abs(coska_h) <= 1
E_allowed_h = E_h[allowed_h]
k_h = np.arccos(coska_h[allowed_h]) / a

# Number of Brillouin zones to display
n_zones = 2

plt.figure(figsize=(12,6))

# Plot minibands for multiple zones
for n in range(-n_zones, n_zones + 1):
    # Electrons
    k_shifted_e = k_e + n*2*np.pi/a
    plt.plot(np.concatenate([-k_shifted_e[::-1], k_shifted_e]),
             np.concatenate([E_allowed_e[::-1], E_allowed_e])/eV, '.', markersize=1, color='b')
    
    # Holes (negative for valence band)
    k_shifted_h = k_h + n*2*np.pi/a
    plt.plot(np.concatenate([-k_shifted_h[::-1], k_shifted_h]),
             -np.concatenate([E_allowed_h[::-1], E_allowed_h])/eV, '.', markersize=1, color='r')

# Optional: shade forbidden zones only in the first zone
plt.fill_betweenx(E_e/eV, -np.pi/a, np.pi/a, where=np.abs(coska_e) > 1, color='blue', alpha=0.1)
plt.fill_betweenx(-E_h/eV, -np.pi/a, np.pi/a, where=np.abs(coska_h) > 1, color='red', alpha=0.1)

# Brillouin zone edges for multiple zones
for n in range(-n_zones, n_zones + 1):
    plt.axvline(n*np.pi/a, color='k', linestyle='--', alpha=0.5)

plt.xlabel('k [1/m]')
plt.ylabel('Energy [eV]')
plt.title('GaAs/AlAs Superlattice: Electron and Hole Minibands Across Multiple Brillouin Zones')
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Constants
hbar = 1.0545718e-34        # Reduced Planck constant [J·s]
eV = 1.60218e-19            # 1 eV in Joules

# Quantum well superlattice parameters (electrons)
m_e_well = 0.067 * 9.10938356e-31
m_e_barrier = 0.091 * 9.10938356e-31
V0_e = 0.3 * eV
b = 5e-9
c = 2e-9
a = b + c

# Quantum well superlattice parameters (holes)
m_h_well = 0.50 * 9.10938356e-31
m_h_barrier = 0.60 * 9.10938356e-31
V0_h = 0.2 * eV

# Energy ranges
E_eV = np.linspace(0.01, 3.5, 10000)  # electrons
E_hV = np.linspace(0.01, 1.5, 10000)  # holes
E_e = E_eV * eV
E_h = E_hV * eV

def kronig_penney(E, m_well, m_barrier, V0):
    cos_ka = np.zeros_like(E)
    for i, Ei in enumerate(E):
        alpha = np.sqrt(2*m_well*Ei)/hbar
        if Ei < V0:
            beta = np.sqrt(2*m_barrier*(V0 - Ei))/hbar
            cos_ka[i] = np.cos(alpha*b)*np.cosh(beta*c) - ((alpha**2 - beta**2)/(2*alpha*beta))*np.sin(alpha*b)*np.sinh(beta*c)
        else:
            kappa = np.sqrt(2*m_barrier*(Ei - V0))/hbar
            cos_ka[i] = np.cos(alpha*b)*np.cos(kappa*c) - ((alpha**2 + kappa**2)/(2*alpha*kappa))*np.sin(alpha*b)*np.sin(kappa*c)
    allowed = np.abs(cos_ka) <= 1
    E_allowed = E[allowed]
    return E_allowed

# Compute allowed energies
E_allowed_e = kronig_penney(E_e, m_e_well, m_e_barrier, V0_e)
E_allowed_h = kronig_penney(E_h, m_h_well, m_h_barrier, V0_h)

# Split allowed energies into minibands
def split_bands(E_allowed, jump_threshold=1e-3*eV):
    bands = []
    band = [E_allowed[0]]
    for i in range(1, len(E_allowed)):
        if E_allowed[i] - E_allowed[i-1] < jump_threshold:
            band.append(E_allowed[i])
        else:
            bands.append(band)
            band = [E_allowed[i]]
    bands.append(band)
    return bands

bands_e = split_bands(E_allowed_e)
bands_h = split_bands(E_allowed_h)

# Average potential
V_avg_e = V0_e * (c/a)
V_avg_h = V0_h * (c/a)

# Plot
plt.figure(figsize=(10,6))

# Forbidden zones for electrons
for i in range(len(bands_e)-1):
    gap_bottom = bands_e[i][-1]/eV - V_avg_e/eV
    gap_top = bands_e[i+1][0]/eV - V_avg_e/eV
    plt.fill_between([-np.pi/a, np.pi/a], gap_bottom, gap_top, color='blue', alpha=0.2)

# Forbidden zones for holes (negative for valence band)
for i in range(len(bands_h)-1):
    gap_bottom = -(bands_h[i+1][0]/eV - V_avg_h/eV)
    gap_top = -(bands_h[i][-1]/eV - V_avg_h/eV)
    plt.fill_between([-np.pi/a, np.pi/a], gap_bottom, gap_top, color='red', alpha=0.2)

# Plot minibands
for band in bands_e:
    k_band = np.linspace(-np.pi/a, np.pi/a, len(band))
    plt.plot(k_band, np.array(band)/eV - V_avg_e/eV, color='b', lw=2)
for band in bands_h:
    k_band = np.linspace(-np.pi/a, np.pi/a, len(band))
    plt.plot(k_band, -np.array(band)/eV + V_avg_h/eV, color='r', lw=2)

# Brillouin zone edges
plt.axvline(-np.pi/a, color='k', linestyle='--', alpha=0.5)
plt.axvline(np.pi/a, color='k', linestyle='--', alpha=0.5)

plt.xlabel('k [1/m]')
plt.ylabel('E(k) [eV]')
plt.title('GaAs/AlAs Superlattice: Electron and Hole Minibands with Forbidden Zones')
plt.grid(True)
plt.show()
